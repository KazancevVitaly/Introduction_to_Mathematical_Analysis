# %% [markdown]
# # GeekBrains
# # Введение в математический анализ. Урок 7.
# ## Домашнее задание.
# ## Казанцев Виталий

# %% [markdown]
# __1.__ Найти частные производные первого и второго порядка. Убедиться в равенстве смешанных производных.
#
# ### $$U=x^3+3xy^2+z^2-39x-36y+2z+26$$

# %% [markdown]
# Решение:
# ### $U'_x = 3x^{2}+3y^{2}-39$
# ### $U'_y = 6xy-36$
# ### $U'_z=2z+2$

# %% [markdown]
# ### $U''_{xx}=6x$
# ### $U''_{yy}=6x$
# ### $U''_{zz}=2$

# %% [markdown]
# ### $U''_{xy}=6y$
# ### $U''_{xz}=0$
# ### $U''_{yx}=6y$
# ### $U''_{yz}=0$
# ### $U''_{zx}=0$
# ### $U''_{zy}=0$
#
# $U''_{xy}=U''_{yx}=6y$
# $U''_{xz}=U''_{zx}=0$
# $U''_{yz}=U''_{zy}=0$

# %% [markdown]
# __2.__ Найти частные производные первого и второго порядка. Убедиться в равенстве смешанных производных.
#
# ### $$U=\frac{256}{x}+\frac{x^2}{y}+\frac{y^2}{z}+z^2$$

# %% [markdown]
# ### $U'_x=-\frac{256}{x^2}+\frac{2x}{y}$
# ### $U'_y=-\frac{x^2}{y^2}+\frac{2y}{z}$
# ### $U'_z=-\frac{y^2}{z^2}+2z$

# %% [markdown]
# ### $U''_{xx}=\frac{512}{x^3}+\frac{2}{y}$
# ### $U''_{yy}=\frac{2x^2}{y^3}+\frac{2}{z}$
# ### $U''_{zz}=\frac{2y^2}{z^3}+2$

# %% [markdown]
# ### $U''_{xy}=-\frac{2x}{y^2}$
# ### $U''_{xz}=0$
# ### $U''_{yx}=-\frac{2x}{y^2}$
# ### $U''_{yz}=-\frac{2y}{z^2}$
# ### $U''_{zx}=0$
# ### $U''_{zy}=-\frac{2y}{z^2}$
#
# $U''_{xy}=U''_{yx}=-\frac{2x}{y^2}$
# $U''_{xz}=U''_{zx}=0$
# $U''_{yz}=U''_{zy}=-\frac{2y}{z^2}$

# %% [markdown]
# __3.__ Найти производную функции $U=x^2+y^2+z^2$ по направлению вектора $\overrightarrow{c}(-9,8,-12)$ в точке $M(8,-12,9)$

# %% [markdown]
# Найдем длину вектора $\overrightarrow{c}$:
# ### $|\overrightarrow{c}|=\sqrt{x^2_{0}+y^2_{0}+z^2_{0}}=\sqrt{(-9)^{2}+8^{2}+(-12)^2}=\sqrt{289}=17$
# Запишем единичный вектор $\overrightarrow{c}_{0}$:
# ### $\overrightarrow{c_{0}}=\frac{\overrightarrow{c}}{|\overrightarrow{c}|}=\Bigr(-\frac{9}{17},\frac{8}{17},-\frac{12}{17}\Bigl)$
# Теперь найдем градиент в точке M(8,-12,9).
# $U'_x=2x$
# $U'_y=2y$
# $U'_z=2z$
# ### $\mbox{grad}U=(16,-24,18)$

# %% [markdown]
# Теперь посчитаем значение производной:
# ### $U'_{\overrightarrow{c}}=-\frac{9}{17}\cdot16+\frac{8}{17}\cdot(-24)-\frac{12}{17}\cdot18=-\frac{552}{17}$
# Ответ:
# ### $U'_{\overrightarrow{c}}=-\frac{552}{17}$

# %% [markdown]
# __4.__ Найти производную функции $U=e^{x^2+y^2+z^2}$ по направлению вектора $\overrightarrow{c}(4,-13,-16)$ в точке $L(-16,4,-13)$

# %% [markdown]
# Найдем длину вектора $\overrightarrow{c}$:
# ### $|\overrightarrow{c}|=\sqrt{x^2_{0}+y^2_{0}+z^2_{0}}=\sqrt{4^{2}+(-13)^{2}+(-16)^2}=\sqrt{441}=21$
# Запишем единичный вектор $\overrightarrow{c}_{0}$:
# ### $\overrightarrow{c_{0}}=\frac{\overrightarrow{c}}{|\overrightarrow{c}|}=\Bigr(\frac{4}{21},-\frac{13}{21},-\frac{16}{21}\Bigl)$

# %% [markdown]
# Теперь найдем градиент в точке L(-16,4,-13).
# $U'_x=2xe^{x^2+y^2+z^2}$
# $U'_y=2ye^{x^2+y^2+z^2}$
# $U'_z=2ze^{x^2+y^2+z^2}$
#
# ### $\mbox{grad}U=(-32e^{441},8e^{441},-26e^{441})$

# %% [markdown]
# Теперь посчитаем значение производной:
# ### $U'_{\overrightarrow{c}}=-\frac{4}{21}\cdot32e^{441}-\frac{13}{21}\cdot8e^{441}+\frac{16}{21}\cdot26e^{441}=\frac{184e^{441}}{21}$
# Ответ:
# ### $U'_{\overrightarrow{c}}=\frac{184e^{441}}{21}$

# %% [markdown]
# __6.__ Исследовать на экстремум функцию:
#
# ### $U=x^2y+\frac{1}{3}y^3+2x^2+3y^2-1$

# %% [markdown]
# Найдём частные производные, приравняем их к нулю и опредедлим стациоонарные точки:
# ### $\begin{cases}
#         U'_x=2xy+4x=0\\
#         U'_y=x^2+y^2+6y=0\end{cases}$

# %% [markdown]
# ### $\begin{cases}
#         x_1=0\\y_1=-6
#         \end{cases}$
# ### $\begin{cases}
#         x_2=0\\y_2=0
#         \end{cases}$
# ### $\begin{cases}
#         x_3=-2\sqrt{2}\\y_3=-2
#         \end{cases}$
# ### $\begin{cases}
#         x_4=2\sqrt{2}\\y_4=-2
#         \end{cases}$

# %% [markdown]
# Теперь найдем вторые производные и составим матрицу Гёссе в общем виде:
# $U''_{xx}=2y+4$
# $U''_{xy}=U''_{yx}=2x$
# $U''_{yy}=2y+6$

# %% [markdown]
# $$\begin{pmatrix}
# 2y+4 & 2x\\
# 2x & 2y+6\\
# \end{pmatrix}$$

# %% [markdown]
# для точки (0;-6)
# ### $\Delta_{1}=U''_{xx}=-12+4=-8<0$
# ### $\Delta_{2}=\begin{vmatrix}
# U''_{xx} & U''_{xy}\\
# U''_{yx} & U''_{yy}\\
# \end{vmatrix}=U''_{xx}\cdot U''_{yy}-(U''_{xy})^2=(-8)\cdot(-4)-0=32>0$
# Перед нами точка максимума

# %% [markdown]
# для точки (0;0)
# ### $\Delta_{1}=U''_{xx}=0+4=4>0$
# ### $\Delta_{2}=\begin{vmatrix}
# U''_{xx} & U''_{xy}\\
# U''_{yx} & U''_{yy}\\
# \end{vmatrix}=U''_{xx}\cdot U''_{yy}-(U''_{xy})^2=4\cdot6-0=24>0$
# Перед нами точка минимума

# %% [markdown]
# для точки $(-2\sqrt{2};-2)$
# ### $\Delta_{1}=U''_{yy}=2>0$
# ### $\Delta_{2}=\begin{vmatrix}
# U''_{yy} & U''_{yx}\\
# U''_{xy} & U''_{xx}\\
# \end{vmatrix}=U''_{yy}\cdot U''_{xx}-(U''_{xy})^2=-2\cdot0+4\sqrt{2}=4\sqrt{2}>0$
# Перед нами точка минимума

# %% [markdown]
# для точки $(2\sqrt{2};-2)$
# ### $\Delta_{1}=U''_{yy}=2>0$
# ### $\Delta_{2}=\begin{vmatrix}
# U''_{yy} & U''_{yx}\\
# U''_{xy} & U''_{xx}\\
# \end{vmatrix}=U''_{yy}\cdot U''_{xx}-(U''_{xy})^2=2\cdot0-4\sqrt{2}=-4\sqrt{2}<0$
# Седловая точка

# %%
import pylab
from mpl_toolkits.mplot3d import Axes3D
import numpy


import warnings
warnings.filterwarnings('ignore')


def makeData():
    x = numpy.arange (-6, 8, 0.1)
    y = numpy.arange (-7, 7, 0.1)
    xgrid, ygrid = numpy.meshgrid(x, y)

    Ugrid = y*xgrid**2+(1/3)*ygrid**3+2*xgrid**2+3*ygrid**2-1
    return xgrid, ygrid, Ugrid

x, y, U = makeData()

fig = pylab.figure()
axes = Axes3D(fig)

axes.plot_surface(x, y, U)

pylab.show()
